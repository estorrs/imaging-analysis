# %%
import os
import pandas as pd

# %%
df = pd.read_csv('/diskmnt/Projects/Users/estorrs/imaging-analysis/data/brca_subtype/cell_segmentation_fps.txt',
                 header=None)
fps = sorted(df.iloc[:, 0].to_list())
fps
# Out:
# ['/scratch1/fs1/dinglab/estorrs/cromwell-data/pecgs/testing/full_imaging_workflow_multisample_all/runs/21d_PKD_Mouse_section1_20230422/cromwell-workdir/cromwell-executions/full_imaging_workflow.cwl/5c24e37e-82d1-45e4-a598-2b46bb5cf112/call-image_processing_to_thresholds/image_processing_no_thresholds_workflow.cwl/93e59c66-7a1a-4e4c-93f4-3695a165818a/call-segment_ome/execution/glob-81332d957321d15a5e00f84fae558251/output_cell_segmentation.tif',
#  '/scratch1/fs1/dinglab/estorrs/cromwell-data/pecgs/testing/full_imaging_workflow_multisample_all/runs/28d_PKD_Mouse_section2_20230422/cromwell-workdir/cromwell-executions/full_imaging_workflow.cwl/5dcece7a-1b5f-4f89-9575-ca62db5e28bb/call-image_processing_to_thresholds/image_processing_no_thresholds_workflow.cwl/26c3da5e-6430-4fbd-bf9b-a3f2a18f2d4b/call-segment_ome/execution/glob-81332d957321d15a5e00f84fae558251/output_cell_segmentation.tif',
# ...

# %%
for fp in fps:
    if '071' in fp or '0526' in fp:
        print(fp)
# Out:
# /scratch1/fs1/dinglab/estorrs/cromwell-data/pecgs/testing/full_imaging_workflow_multisample_all/runs/HT171B1_S1H9A1_A4_left_20230526/cromwell-workdir/cromwell-executions/full_imaging_workflow.cwl/ef6e2d9c-5781-4027-9b0a-accadb4e5d1c/call-image_processing_to_thresholds/image_processing_no_thresholds_workflow.cwl/eaa68867-9e9d-4259-9951-f01d95c8514b/call-segment_ome/execution/glob-81332d957321d15a5e00f84fae558251/output_cell_segmentation.tif
# /scratch1/fs1/dinglab/estorrs/cromwell-data/pecgs/testing/full_imaging_workflow_multisample_all/runs/HT171B1_S1H9A1_A4_right_20230526/cromwell-workdir/cromwell-executions/full_imaging_workflow.cwl/053c0e8d-431f-41e2-8125-f545339f4f09/call-image_processing_to_thresholds/image_processing_no_thresholds_workflow.cwl/277a9d89-1643-4c0a-af4a-b755f9c1d3e9/call-segment_ome/execution/glob-81332d957321d15a5e00f84fae558251/output_cell_segmentation.tif
# ...

# %%
katmai = '/diskmnt/Projects/Users/estorrs/multiplex_data/codex/htan/brca/07012023_BRCA_HT206B1-S1H5_TOP_HT297B1-S1H1_HT339B2-H2_HT565B1-S1H2_BTTM/level_3/segmentation'

for fp in fps:
    if '071' in fp:
        root = fp.split('/')[10]
        print(f'scp estorrs@compute1-client-1.ris.wustl.edu:{fp} {katmai}/{root}_cell_segmentation.tif')
# Out:
# scp estorrs@compute1-client-1.ris.wustl.edu:/scratch1/fs1/dinglab/estorrs/cromwell-data/pecgs/testing/full_imaging_workflow_multisample_all/runs/HT206B1_S1H5_left_2023071/cromwell-workdir/cromwell-executions/full_imaging_workflow.cwl/72211d26-4a92-43e9-9911-f5e9d49f8694/call-image_processing_to_thresholds/image_processing_no_thresholds_workflow.cwl/c5d7344f-c1de-4905-8bab-c364de118b0c/call-segment_ome/execution/glob-81332d957321d15a5e00f84fae558251/output_cell_segmentation.tif /diskmnt/Projects/Users/estorrs/multiplex_data/codex/htan/brca/07012023_BRCA_HT206B1-S1H5_TOP_HT297B1-S1H1_HT339B2-H2_HT565B1-S1H2_BTTM/level_3/segmentation/HT206B1_S1H5_left_2023071_cell_segmentation.tif
# ...

# %%
df = pd.read_csv('/diskmnt/Projects/Users/estorrs/imaging-analysis/data/brca_subtype/filepaths.txt', header=None)
fps = sorted(df.iloc[:, 0].to_list())
fps
# Out:
# ['/scratch1/fs1/dinglab/estorrs/cromwell-data/pecgs/testing/full_imaging_workflow_multisample_all/runs/21d_PKD_Mouse_section1_20230422/cromwell-workdir/cromwell-executions/full_imaging_workflow.cwl/5c24e37e-82d1-45e4-a598-2b46bb5cf112/call-image_processing_to_thresholds/image_processing_no_thresholds_workflow.cwl/93e59c66-7a1a-4e4c-93f4-3695a165818a/call-generate_spatial_features/execution/glob-ef5df339533c1334f081dc8cc75ee4f3/output_spatial_features.txt',
#  '/scratch1/fs1/dinglab/estorrs/cromwell-data/pecgs/testing/full_imaging_workflow_multisample_all/runs/28d_PKD_Mouse_section2_20230422/cromwell-workdir/cromwell-executions/full_imaging_workflow.cwl/5dcece7a-1b5f-4f89-9575-ca62db5e28bb/call-image_processing_to_thresholds/image_processing_no_thresholds_workflow.cwl/26c3da5e-6430-4fbd-bf9b-a3f2a18f2d4b/call-generate_spatial_features/execution/glob-ef5df339533c1334f081dc8cc75ee4f3/output_spatial_features.txt',
# ...

# %%
for fp in fps:
    if '071' in fp:
        print(fp)
# Out:
# /scratch1/fs1/dinglab/estorrs/cromwell-data/pecgs/testing/full_imaging_workflow_multisample_all/runs/HT206B1_S1H5_left_2023071/cromwell-workdir/cromwell-executions/full_imaging_workflow.cwl/72211d26-4a92-43e9-9911-f5e9d49f8694/call-image_processing_to_thresholds/image_processing_no_thresholds_workflow.cwl/c5d7344f-c1de-4905-8bab-c364de118b0c/call-generate_spatial_features/execution/glob-ef5df339533c1334f081dc8cc75ee4f3/output_spatial_features.txt
# /scratch1/fs1/dinglab/estorrs/cromwell-data/pecgs/testing/full_imaging_workflow_multisample_all/runs/HT206B1_S1H5_right_2023071/cromwell-workdir/cromwell-executions/full_imaging_workflow.cwl/a2d098fb-4abe-4f3d-99f9-f2cd78c130fb/call-image_processing_to_thresholds/image_processing_no_thresholds_workflow.cwl/3c2018b7-b5f8-4d72-98d7-ffc08fb0573c/call-generate_spatial_features/execution/glob-ef5df339533c1334f081dc8cc75ee4f3/output_spatial_features.txt
# ...
